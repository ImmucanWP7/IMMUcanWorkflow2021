# %% [markdown]
# ## Comparison of IMC and mIF images
#
# This script reads in IMC and mIF images and displayes them in napari.

# %%
#%run classes.py
# %run napari_comparison.py

# %%
sample_name = "IMMUcan_Batch20210701_10075572-SPECT-VAR-TIS-UNST-03_001"

napari_comparison("/Volumes/GoogleDrive/My Drive/IMMUcan_workflow/data/comparisons/data_for_comparisons",
                 sample_name = sample_name)

# %%
# !conda list
# Out:
# # packages in environment at /Users/nils/opt/anaconda3/envs/napari_comparison:
# #
# # Name                    Version                   Build  Channel
# alabaster                 0.7.13                   pypi_0    pypi
# anndata                   0.8.0                    pypi_0    pypi
# anyio                     3.5.0            py39hecd8cb5_0
# app-model                 0.1.1                    pypi_0    pypi
# appdirs                   1.4.4                    pypi_0    pypi
# appnope                   0.1.2           py39hecd8cb5_1001
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0           py39hca72f7f_0
# asttokens                 2.0.5              pyhd3eb1b0_0
# attrs                     22.1.0           py39hecd8cb5_0
# babel                     2.11.0           py39hecd8cb5_0
# backcall                  0.2.0              pyhd3eb1b0_0
# beautifulsoup4            4.11.1           py39hecd8cb5_0
# ...
