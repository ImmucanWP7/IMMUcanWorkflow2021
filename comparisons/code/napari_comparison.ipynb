# %% [markdown]
# ## Comparison of IMC and mIF images
#
# This script reads in IMC and mIF images and displayes them in napari.

# %%
import cv2
import napari
import numpy as np
import pandas as pd

from steinbock.io import read_panel, read_image, read_mask

# %run napari_comparison.py
# %run classes.py

# %%
sample_name = "IMMUcan_Batch20210701_10075572-SPECT-VAR-TIS-UNST-03_004"
path_to_imc = "/Volumes/immucan_volume/processed_data/Panel_1/2022_WORKFLOW/comparisons/IMC/"
path_to_mIF = "/Volumes/immucan_volume/processed_data/Panel_1/2022_WORKFLOW/comparisons/mIF/"

imc_image = read_image(path_to_imc + "img/" + sample_name + ".tiff")
imc_dir = path_to_imc + "img/"
imc_panel = read_panel(path_to_imc + "panel.csv")
imc_cells = pd.read_table(path_to_imc + "cells/" + sample_name + ".tsv")
mif_image = read_image(path_to_mIF + "img/" + sample_name + ".tiff")
mif_dir = path_to_mIF + "img/"
mif_panel = read_panel(path_to_mIF + "panel.csv")
mif_cells = pd.read_table(path_to_mIF + "cells/" + sample_name + ".tsv")

# %%
napari_comparison(imc_image, imc_dir, imc_panel, imc_cells, mif_image, mif_dir, mif_panel, mif_cells)
# Out:
# /Users/nils/Github/IMMUcanWorkflow2021/comparisons/code/napari_comparison.py:422: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   viewer2.window.qt_viewer.view.camera.link(viewer1.window.qt_viewer.view.camera)
# Traceback (most recent call last):
#   File "/Users/nils/Github/IMMUcanWorkflow2021/comparisons/code/napari_comparison.py", line 174, in _on_next_button_clicked
#     self._app.navigator.next()
# AttributeError: 'Viewer' object has no attribute 'navigator'

# %%
# !conda list
# Out:
# # packages in environment at /Users/nils/opt/anaconda3/envs/napari_comparison:
# #
# # Name                    Version                   Build  Channel
# alabaster                 0.7.12                   pypi_0    pypi
# anndata                   0.8.0                    pypi_0    pypi
# anyio                     3.6.2                    pypi_0    pypi
# appdirs                   1.4.4                    pypi_0    pypi
# appnope                   0.1.3                    pypi_0    pypi
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0           py39hca72f7f_0
# asttokens                 2.1.0                    pypi_0    pypi
# attrs                     22.1.0                   pypi_0    pypi
# babel                     2.11.0                   pypi_0    pypi
# backcall                  0.2.0              pyhd3eb1b0_0
# beautifulsoup4            4.11.1           py39hecd8cb5_0
# ...
